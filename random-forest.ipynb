# %%
# ModuleNotFoundError: No module named 'seaborn'
conda install seaborn
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.12.0
#   latest version: 24.7.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env
#
#   added / updated specs:
#     - seaborn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2024.7.2   |       hca03da5_0         128 KB
#     certifi-2024.7.4           |  py310hca03da5_0         160 KB
#     openssl-1.1.1w             |       h1a28f6b_0         3.1 MB
#     seaborn-0.13.2             |  py310hca03da5_0         601 KB
#     ------------------------------------------------------------
#                                            Total:         4.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   seaborn            pkgs/main/osx-arm64::seaborn-0.13.2-py310hca03da5_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2022.07.19-hca03da5_0 --> 2024.7.2-hca03da5_0
#   certifi                         2022.9.14-py310hca03da5_0 --> 2024.7.4-py310hca03da5_0
#   openssl                                 1.1.1q-h1a28f6b_0 --> 1.1.1w-h1a28f6b_0
#
#
#
# Downloading and Extracting Packages
# seaborn-0.13.2       | 601 KB    | ##################################### | 100%
# openssl-1.1.1w       | 3.1 MB    | ##################################### | 100%
# certifi-2024.7.4     | 160 KB    | ##################################### | 100%
# ca-certificates-2024 | 128 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline

# pip install seaborn

# %%
f_detail = pd.read_csv('./datasets/AdvWorksCusts.csv')
f_detail
# Out:
#        CustomerID Title  FirstName MiddleName    LastName Suffix  \
# 0           11000   NaN        Jon          V        Yang    NaN
# 1           11001   NaN     Eugene          L       Huang    NaN
# 2           11002   NaN      Ruben        NaN      Torres    NaN
# 3           11003   NaN    Christy        NaN         Zhu    NaN
# 4           11004   NaN  Elizabeth        NaN     Johnson    NaN
# ...           ...   ...        ...        ...         ...    ...
# 16514       13121   NaN    Latasha          E     Jimenez    NaN
# 16515       26100   NaN      James     Garner  Ptaszynski    NaN
# 16516       11328   NaN     Julian          M     Griffin    NaN
# 16517       23077   NaN     Marvin          A   Hernandez    NaN
# 16518       18982   NaN       Kyle        NaN       Baker    NaN
#
#               AddressLine1 AddressLine2         City StateProvinceName  ...  \
# 0          3761 N. 14th St          NaN  Rockhampton        Queensland  ...
# 1               2243 W St.          NaN      Seaford          Victoria  ...
# 2         5844 Linden Land          NaN       Hobart          Tasmania  ...
# 3         1825 Village Pl.          NaN   North Ryde   New South Wales  ...
# 4      7553 Harness Circle          NaN   Wollongong   New South Wales  ...
# ...                    ...          ...          ...               ...  ...
# 16514       7259 Birchwood          NaN       Melton          Victoria  ...
# 16515      7345 Kenwal Rd.          NaN      Shawnee  British Columbia  ...
# 16516  7398 Withersed Lane          NaN       Newton  British Columbia  ...
# 16517       1019 Book Road          NaN       Rhodes   New South Wales  ...
# 16518      2118 Little Dr.          NaN     Kirkland        Washington  ...
#
#         BirthDate        Education      Occupation Gender MaritalStatus  \
# 0      1966-04-08       Bachelors     Professional      M             M
# 1      1965-05-14       Bachelors     Professional      M             S
# 2      1965-08-12       Bachelors     Professional      M             M
# 3      1968-02-15       Bachelors     Professional      F             S
# 4      1968-08-08       Bachelors     Professional      F             S
# ...           ...              ...             ...    ...           ...
# 16514  1965-03-22       Bachelors     Professional      F             M
# 16515  1936-04-02  Partial College    Professional      F             S
# 16516  1940-01-01       Bachelors       Management      M             M
# 16517  1946-10-20      High School  Skilled Manual      M             M
# 16518  1945-04-07      High School    Professional      M             S
#
#       HomeOwnerFlag NumberCarsOwned NumberChildrenAtHome  TotalChildren  \
# 0                 1               0                    0              2
# 1                 0               1                    3              3
# 2                 1               1                    3              3
# 3                 0               1                    0              0
# 4                 1               4                    5              5
# ...             ...             ...                  ...            ...
# 16514             1               4                    5              5
# 16515             1               2                    0              3
# 16516             1               2                    0              5
# 16517             1               2                    0              4
# 16518             1               2                    0              4
#
#        YearlyIncome
# 0            137947
# 1            101141
# 2             91945
# 3             86688
# 4             92771
# ...             ...
# 16514        101542
# 16515         46549
# 16516        133053
# 16517         31930
# 16518         59382
#
# [16519 rows x 23 columns]

# %%
f_status = pd.read_csv('./datasets/AW_BikeBuyer.csv')
f_status
# Out:
#        CustomerID  BikeBuyer
# 0           11000          0
# 1           11001          1
# 2           11002          0
# 3           11003          0
# 4           11004          1
# ...           ...        ...
# 16514       13121          0
# 16515       26100          0
# 16516       11328          0
# 16517       23077          0
# 16518       18982          0
#
# [16519 rows x 2 columns]

# %%
data = pd.concat([f_detail, f_status['BikeBuyer']], axis=1)
data
# Out:
#        CustomerID Title  FirstName MiddleName    LastName Suffix  \
# 0           11000   NaN        Jon          V        Yang    NaN
# 1           11001   NaN     Eugene          L       Huang    NaN
# 2           11002   NaN      Ruben        NaN      Torres    NaN
# 3           11003   NaN    Christy        NaN         Zhu    NaN
# 4           11004   NaN  Elizabeth        NaN     Johnson    NaN
# ...           ...   ...        ...        ...         ...    ...
# 16514       13121   NaN    Latasha          E     Jimenez    NaN
# 16515       26100   NaN      James     Garner  Ptaszynski    NaN
# 16516       11328   NaN     Julian          M     Griffin    NaN
# 16517       23077   NaN     Marvin          A   Hernandez    NaN
# 16518       18982   NaN       Kyle        NaN       Baker    NaN
#
#               AddressLine1 AddressLine2         City StateProvinceName  ...  \
# 0          3761 N. 14th St          NaN  Rockhampton        Queensland  ...
# 1               2243 W St.          NaN      Seaford          Victoria  ...
# 2         5844 Linden Land          NaN       Hobart          Tasmania  ...
# 3         1825 Village Pl.          NaN   North Ryde   New South Wales  ...
# 4      7553 Harness Circle          NaN   Wollongong   New South Wales  ...
# ...                    ...          ...          ...               ...  ...
# 16514       7259 Birchwood          NaN       Melton          Victoria  ...
# 16515      7345 Kenwal Rd.          NaN      Shawnee  British Columbia  ...
# 16516  7398 Withersed Lane          NaN       Newton  British Columbia  ...
# 16517       1019 Book Road          NaN       Rhodes   New South Wales  ...
# 16518      2118 Little Dr.          NaN     Kirkland        Washington  ...
#
#              Education      Occupation Gender MaritalStatus HomeOwnerFlag  \
# 0           Bachelors     Professional      M             M             1
# 1           Bachelors     Professional      M             S             0
# 2           Bachelors     Professional      M             M             1
# 3           Bachelors     Professional      F             S             0
# 4           Bachelors     Professional      F             S             1
# ...                ...             ...    ...           ...           ...
# 16514       Bachelors     Professional      F             M             1
# 16515  Partial College    Professional      F             S             1
# 16516       Bachelors       Management      M             M             1
# 16517      High School  Skilled Manual      M             M             1
# 16518      High School    Professional      M             S             1
#
#       NumberCarsOwned NumberChildrenAtHome TotalChildren  YearlyIncome  \
# 0                   0                    0             2        137947
# 1                   1                    3             3        101141
# 2                   1                    3             3         91945
# 3                   1                    0             0         86688
# 4                   4                    5             5         92771
# ...               ...                  ...           ...           ...
# 16514               4                    5             5        101542
# 16515               2                    0             3         46549
# 16516               2                    0             5        133053
# 16517               2                    0             4         31930
# 16518               2                    0             4         59382
#
#        BikeBuyer
# 0              0
# 1              1
# 2              0
# 3              0
# 4              1
# ...          ...
# 16514          0
# 16515          0
# 16516          0
# 16517          0
# 16518          0
#
# [16519 rows x 24 columns]

# %%
# sns.boxplot(x=data["Gender"])
# sns.color_palette()
sns.set_style("whitegrid")
# sns.boxplot(x='BikeBuyer', "Gender", data=data["Gender"])
col_x = 'BikeBuyer'
col = "Gender"
dataX = data[col]


sns.boxplot(data=data, x=col_x, y=col, palette="pastel", hue=col)
plt.xlabel(col_x)
plt.ylabel(col)
plt.show()

# %%
def plot_box(data, cols, col_x = 'BikeBuyer'):
    for col in cols:
        sns.set_style("whitegrid")
#         sns.color_palette()
#         sns.boxplot(col_x, col, data=data)
        sns.boxplot(data=data, x=col_x, y=col, palette="pastel")
#         sns.boxplot(data=data, x=col_x, y=col, palette="pastel", hue=col)
        plt.xlabel(col_x) # Set text for the x axis
        plt.ylabel(col)# Set text for y axis
        plt.show()

# %%
num_cols = ['Gender','MaritalStatus','Occupation', 'HomeOwnerFlag',
 'NumberCarsOwned',
 'NumberChildrenAtHome',
 'TotalChildren',
 'YearlyIncome']
plot_box(data, cols=num_cols)
# Out:
# /var/folders/95/l2p_37ln4812_95hkk3sn6r80000gn/T/ipykernel_14965/1032250086.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x=col_x, y=col, palette="pastel")
# /var/folders/95/l2p_37ln4812_95hkk3sn6r80000gn/T/ipykernel_14965/1032250086.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x=col_x, y=col, palette="pastel")
# /var/folders/95/l2p_37ln4812_95hkk3sn6r80000gn/T/ipykernel_14965/1032250086.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x=col_x, y=col, palette="pastel")
# /var/folders/95/l2p_37ln4812_95hkk3sn6r80000gn/T/ipykernel_14965/1032250086.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x=col_x, y=col, palette="pastel")
# /var/folders/95/l2p_37ln4812_95hkk3sn6r80000gn/T/ipykernel_14965/1032250086.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x=col_x, y=col, palette="pastel")
# /var/folders/95/l2p_37ln4812_95hkk3sn6r80000gn/T/ipykernel_14965/1032250086.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x=col_x, y=col, palette="pastel")
# /var/folders/95/l2p_37ln4812_95hkk3sn6r80000gn/T/ipykernel_14965/1032250086.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x=col_x, y=col, palette="pastel")
# /var/folders/95/l2p_37ln4812_95hkk3sn6r80000gn/T/ipykernel_14965/1032250086.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x=col_x, y=col, palette="pastel")

# %%
data = pd.concat([data,pd.get_dummies(data['Occupation'], prefix='Occupation',
                                 dummy_na=True)],axis=1).drop(['Occupation'],axis=1)
data = pd.concat([data,pd.get_dummies(data['Gender'], prefix='Gender',
                                 dummy_na=True)],axis=1).drop(['Gender'],axis=1)
data = pd.concat([data,pd.get_dummies(data['MaritalStatus'], prefix='MaritalStatus',
                                 dummy_na=True)],axis=1).drop(['MaritalStatus'],axis=1)
data.head()
# Out:
#    CustomerID Title  FirstName MiddleName LastName Suffix  \
# 0       11000   NaN        Jon          V     Yang    NaN
# 1       11001   NaN     Eugene          L    Huang    NaN
# 2       11002   NaN      Ruben        NaN   Torres    NaN
# 3       11003   NaN    Christy        NaN      Zhu    NaN
# 4       11004   NaN  Elizabeth        NaN  Johnson    NaN
#
#           AddressLine1 AddressLine2         City StateProvinceName  ...  \
# 0      3761 N. 14th St          NaN  Rockhampton        Queensland  ...
# 1           2243 W St.          NaN      Seaford          Victoria  ...
# 2     5844 Linden Land          NaN       Hobart          Tasmania  ...
# 3     1825 Village Pl.          NaN   North Ryde   New South Wales  ...
# 4  7553 Harness Circle          NaN   Wollongong   New South Wales  ...
#
#   Occupation_Manual Occupation_Professional Occupation_Skilled Manual  \
# 0                 0                       1                         0
# 1                 0                       1                         0
# 2                 0                       1                         0
# 3                 0                       1                         0
# 4                 0                       1                         0
#
#   Occupation_nan Gender_F  Gender_M  Gender_nan  MaritalStatus_M  \
# 0              0        0         1           0                1
# 1              0        0         1           0                0
# 2              0        0         1           0                1
# 3              0        1         0           0                0
# 4              0        1         0           0                0
#
#    MaritalStatus_S  MaritalStatus_nan
# 0                0                  0
# 1                1                  0
# 2                0                  0
# 3                1                  0
# 4                1                  0
#
# [5 rows x 33 columns]

# %%
list(data)
# Out:
# ['CustomerID',
#  'Title',
#  'FirstName',
#  'MiddleName',
#  'LastName',
#  'Suffix',
#  'AddressLine1',
#  'AddressLine2',
#  'City',
#  'StateProvinceName',
#  'CountryRegionName',
#  'PostalCode',
#  'PhoneNumber',
#  'BirthDate',
#  'Education',
#  'HomeOwnerFlag',
#  'NumberCarsOwned',
#  'NumberChildrenAtHome',
#  'TotalChildren',
#  'YearlyIncome',
#  'BikeBuyer',
#  'Occupation_Clerical',
#  'Occupation_Management',
#  'Occupation_Manual',
#  'Occupation_Professional',
#  'Occupation_Skilled Manual',
#  'Occupation_nan',
#  'Gender_F',
#  'Gender_M',
#  'Gender_nan',
#  'MaritalStatus_M',
#  'MaritalStatus_S',
#  'MaritalStatus_nan']

# %%
X=data[['Occupation_Clerical','Occupation_Management',
 'Occupation_Manual','Occupation_Professional',
 'Occupation_Skilled Manual','Occupation_nan',
 'Gender_F','Gender_M',
 'Gender_nan','MaritalStatus_M',
'MaritalStatus_S','MaritalStatus_nan','NumberCarsOwned','NumberChildrenAtHome','YearlyIncome']]
y=data['BikeBuyer']


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
X_train.shape
# Out:
# (11067, 15)

# %% [markdown]
# # Trainning Modal
#
# <br />
#
# n_estimators = จำนวนต้นไม้ใน Random Forest,
#
# max_features = วิธีการโหวต
#
# max_depth = ความลึกของต้นไม้แต่ละต้น
#
# criterion = วิธีการตัดสินใจของต้นไม้แต่ละต้น

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import numpy as np

# %%
rfc=RandomForestClassifier(random_state=42)

# %%
param_grid = { 
 'n_estimators': [100,200,300,400,500,600],
 'max_features': ['auto', 'sqrt', 'log2'],
 'max_depth' : [2,3,4,5,6,7,8,9,10],
 'criterion' :['gini', 'entropy']
}

# %% [markdown]
# # turnning performance

# %%
CV_rfc = GridSearchCV(estimator=rfc, param_grid=param_grid, cv= 5)
CV_rfc.fit(X_train, y_train)
CV_rfc.best_params_
# Out:
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# ...
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# {'criterion': 'gini',
#  'max_depth': 7,
#  'max_features': 'auto',
#  'n_estimators': 400}

# %% [markdown]
# ---

# %% [markdown]
# ## Apply best params to modal

# %%
rfc1=RandomForestClassifier(random_state=42, max_features='auto', n_estimators= 400, max_depth=7, criterion='gini')
rfc1.fit(X_train, y_train)

pred=rfc1.predict(X_test)
print("Accuracy for Random Forest on CV data: ",accuracy_score(y_test,pred))
# Out:
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# Accuracy for Random Forest on CV data:  0.7865003668378576

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## hyper parameter => randomsearchCV

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
random_search = RandomizedSearchCV(estimator=rfc, param_distributions=param_grid, cv=5)
random_search.fit(X_train, y_train)
random_search.best_estimator_
# Out:
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/wutcharara/Documents/HAM/HAM_TEST/test_jupyter_notebook/example-1/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# RandomForestClassifier(max_depth=7, max_features='auto', n_estimators=400,
#                        random_state=42)
